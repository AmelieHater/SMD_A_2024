# %%
import pandas as pdBINS
import matplotlib.pyplot as plt
import numpy as np

# %%
BINS = [5,10,15,20,30,50]

# %%
x_nan,y_nan = np.genfromtxt("height_weight.csv", delimiter = ",", unpack = True)
x = x_nan[1:]
y = y_nan[1:]
#print(x,y)
# Out:
# [1.72 1.84 1.68 1.84 1.81 1.9  1.77 1.84 1.88 1.87 1.89 1.93 1.77 1.81
#  1.77 1.68 1.8  1.8  1.72 1.87 1.73 1.77 1.73 1.78 1.72 1.82 1.71 1.71
#  1.64 1.75 1.87 1.81 1.81 1.8  1.87 1.65 1.78 1.73 1.84 1.7  1.75 1.78
#  1.82 1.73 1.86 1.71 1.81 1.74 1.7  1.84 1.75 1.72 1.87 1.71 1.83 1.73
#  1.77 1.8  1.67 1.86 1.74 1.78 1.7  1.78 1.71 1.8  1.82 1.76 1.82 1.82
#  1.75 1.87 1.63 1.67 1.71 1.77 1.74 1.78 1.76 1.72 1.71 1.85 1.78 1.76
#  1.71 1.71 1.67 1.84 1.85 1.78 1.77 1.79 1.82 1.89 1.97 1.86 1.69 1.73
#  1.83 1.87 1.83 1.81 1.87 1.76 1.74 1.87 1.89 1.92 1.76 1.74 1.78 1.78
#  1.78 1.82 1.76 1.85 1.83 1.88 1.84 1.89 1.82 1.75 1.7  1.69 1.7  1.75
#  1.72 1.86 1.77 1.82 1.79 1.86 1.7  1.77 1.77 1.8  1.88 1.81 1.9  1.8
#  1.77 1.72 1.84 1.97 1.8  1.85 1.77 1.84 1.78 1.75 1.89 1.84 1.71 1.87
#  1.91 1.75 1.84 1.75 1.82 1.84 1.85 1.75 1.79 1.83 1.87 1.73 1.84 1.77
#  1.77 1.72 1.66 1.8  1.82 1.82 1.76 1.7  1.82 1.76 1.89 1.89 1.73 1.71
# ...

# %%
distribution = [x,y]

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(3,2,constrained_layout=True)
ax1.hist(x, bins=5)
ax2.hist(x, bins=5)
ax3.hist(x, bins=5)
ax4.hist(x, bins=5)
ax5.hist(x, bins=5)
ax6.hist(x, bins=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(3,2,constrained_layout=True)
#       2 ax1.hist(distribution, bins=5)
#       3 ax2.hist(distribution, bins=5)
#
# ValueError: too many values to unpack (expected 2)
